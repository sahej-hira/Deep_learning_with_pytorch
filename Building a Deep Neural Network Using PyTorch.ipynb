# %% [markdown]
# # Building a neural network for a classification problem

# %%
## Import the PyTorch library, called torch, as well as the nn module from PyTorch:

import torch
import torch.nn as nn

# %%
# importing dataset form another file

# %run Splitting_a_dataset.ipynb
# Out:
# <bound method NDFrame.head of        Appliances  lights         T1       RH_1         T2       RH_2  \
# 0              60      30  19.890000  47.596667  19.200000  44.790000
# 1              60      30  19.890000  46.693333  19.200000  44.722500
# 2              50      30  19.890000  46.300000  19.200000  44.626667
# 3              50      40  19.890000  46.066667  19.200000  44.590000
# 4              60      40  19.890000  46.333333  19.200000  44.530000
# ...           ...     ...        ...        ...        ...        ...
# 19730         100       0  25.566667  46.560000  25.890000  42.025714
# 19731          90       0  25.500000  46.500000  25.754000  42.080000
# 19732         270      10  25.500000  46.596667  25.628571  42.768571
# 19733         420      10  25.500000  46.990000  25.414000  43.036000
# 19734         430      10  25.500000  46.600000  25.264286  42.971429
#
#               T3       RH_3         T4       RH_4  ...         T9     RH_9  \
# ...

# %%
data
# data = data.drop(columns=['date'])
# Out:
#        Appliances  lights         T1       RH_1         T2       RH_2  \
# 0              60      30  19.890000  47.596667  19.200000  44.790000
# 1              60      30  19.890000  46.693333  19.200000  44.722500
# 2              50      30  19.890000  46.300000  19.200000  44.626667
# 3              50      40  19.890000  46.066667  19.200000  44.590000
# 4              60      40  19.890000  46.333333  19.200000  44.530000
# ...           ...     ...        ...        ...        ...        ...
# 19730         100       0  25.566667  46.560000  25.890000  42.025714
# 19731          90       0  25.500000  46.500000  25.754000  42.080000
# 19732         270      10  25.500000  46.596667  25.628571  42.768571
# 19733         420      10  25.500000  46.990000  25.414000  43.036000
# 19734         430      10  25.500000  46.600000  25.264286  42.971429
#
#               T3       RH_3         T4       RH_4  ...         T9     RH_9  \
# ...

# %%
data = pd.read_csv(r"updated_file.csv")
# redo the

# %%
# additional
data
# Out:
#        Appliances  lights         T1       RH_1         T2       RH_2  \
# 0              60      30  19.890000  47.596667  19.200000  44.790000
# 1              60      30  19.890000  46.693333  19.200000  44.722500
# 2              50      30  19.890000  46.300000  19.200000  44.626667
# 3              50      40  19.890000  46.066667  19.200000  44.590000
# 4              60      40  19.890000  46.333333  19.200000  44.530000
# ...           ...     ...        ...        ...        ...        ...
# 19730         100       0  25.566667  46.560000  25.890000  42.025714
# 19731          90       0  25.500000  46.500000  25.754000  42.080000
# 19732         270      10  25.500000  46.596667  25.628571  42.768571
# 19733         420      10  25.500000  46.990000  25.414000  43.036000
# 19734         430      10  25.500000  46.600000  25.264286  42.971429
#
#               T3       RH_3         T4       RH_4  ...         T9     RH_9  \
# ...

# %%
# additional
y_train
# Out:
# 460      100
# 15507     60
# 11050    230
# 5970      50
# 4742      80
#         ...
# 19098     50
# 4109      50
# 16495     60
# 16715    110
# 10337    100
# Name: Appliances, Length: 11841, dtype: int64

# %%
## additional: not necessary
print(type(X_train))
print(type(y_train))
# Out:
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>

# %%
## Separate the feature columns from the target, for each of the sets created in the previous exercise.
## Additionally, convert the final DataFrames into tensors:
X_train = torch.tensor(x_train.values).float()
y_train = torch.tensor(y_train.values).float()
x_dev = torch.tensor(x_dev.values).float()
y_dev = torch.tensor(y_dev.values).float()
x_test = torch.tensor(x_test.values).float()
y_test = torch.tensor(y_test.values).float()

## in capital
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[103], line 4
#       1 ## Separate the feature columns from the target, for each of the sets created in the previous exercise.
#       2 ## Additionally, convert the final DataFrames into tensors:
#       3 X_train = torch.tensor(x_train.values).float()
# ----> 4 y_train = torch.tensor(y_train.values).float()
#       5 x_dev = torch.tensor(x_dev.values).float()
#       6 y_dev = torch.tensor(y_dev.values).float()
#
# RuntimeError: Could not infer dtype of builtin_function_or_method

# %%
## additional: not necessary
print(type(X_train))
print(type(y_train))
# Out:
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>

# %%
## Define the architecture of the network. Feel free to try different combinations for the number of layers and the number of units per layer:
model = nn.Sequential(nn.Linear(x_train.shape[1], 10),
                        nn.ReLU(),
                        nn.Linear(10, 7),
                        nn.ReLU(),
                        nn.Linear(7, 5),
                        nn.ReLU(),
                        nn.Linear(5, 1))

# %%
## Define the loss function and the optimizer algorithm:
loss_function = torch.nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

print(optimizer)
# Out:
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 0.01
#     maximize: False
#     weight_decay: 0
# )

# %%
# additional
print(X_train.shape)
print(y_pred.shape)
print(y_test.shape)
# Out:
# torch.Size([11841, 27])
# torch.Size([11841, 1])
# torch.Size([3947])

# %%
## Use a for loop to train the network for 100 iteration steps:##doing it a 1000
for i in range(100):
    y_pred = model(X_train)
    loss = loss_function(y_pred, y_train)
    print(i, loss.item())
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
# Out:
# 0 20509.287109375
# 1 20509.287109375
# 2 20509.287109375
# 3 20509.287109375
# 4 20509.287109375
# 5 20509.287109375
# 6 20509.287109375
# 7 20509.287109375
# 8 20509.287109375
# 9 20509.287109375
# 10 20509.287109375
# 11 20509.287109375
# 12 20509.287109375
# 13 20509.287109375
# 14 20509.287109375
# 15 20509.287109375
# 16 20509.287109375
# 17 20509.287109375
# 18 20509.287109375
# 19 20509.287109375
# 20 20509.287109375
# 21 20509.287109375
# 22 20509.287109375
# 23 20509.287109375
# 24 20509.287109375
# 25 20509.287109375
# 26 20509.287109375
# 27 20509.287109375
# 28 20509.287109375
# 29 20509.287109375
# 30 20509.287109375
# 31 20509.287109375
# 32 20509.287109375
# 33 20509.287109375
# 34 20509.287109375
# 35 20509.287109375
# 36 20509.287109375
# 37 20509.287109375
# 38 20509.287109375
# 39 20509.287109375
# 40 20509.287109375
# 41 20509.287109375
# 42 20509.287109375
# 43 20509.287109375
# 44 20509.287109375
# 45 20509.287109375
# 46 20509.287109375
# 47 20509.287109375
# ...

# %%
## Test your model by performing a prediction on the first instance of the testing set and comparing it to the ground truth:
pred = model(x_test[0])
print(y_test[0], pred)
# Out:
# tensor(710.) tensor([-1.1839], grad_fn=<ViewBackward0>)
